# %%
# %matplotlib inline

# %%
import numpy as np
import nibabel as nib
from extract_from_masks import *

# %%
atlas_file = 'HarvardOxford-cort-maxprob-thr25-2mm.nii.gz'

masks = generate_masks(atlas_file)

# %%
import matplotlib.pyplot as plt

for m in masks:
    plt.imshow(m.get_data()[26,:,:])
    plt.show()

# %%
import os.path as op
from nilearn import image


parentdir = op.expanduser('~/Dropbox/data_analysis/brainhack_2017_data/jason')

img_name = op.join(parentdir,'cope10.nii')

img = nib.load(img_name)

# %%
check = extract_from_masks(masks[:5],img_name,average = False,dataframe=False)

# %%
np.mean(check['mask001'],axis=1).shape
# Out:
# (31,)

# %%
check.items
